# %%
# %pip install gspread
# %pip install oauth2client

import requests
import json
import csv
import pandas as pd
import gspread
import time
from oauth2client.service_account import ServiceAccountCredentials

ccaSearch = []
ccaSearch2 = []

scope = ['https://www.googleapis.com/auth/spreadsheets','https://www.googleapis.com/auth/drive.file','https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('yourGooglesheetJSONpath',scope)
client = gspread.authorize(creds)
sh = client.open('yourgooglesheetfile')
worksheet = sh.get_worksheet(googletab)

api = "yourFMPAPItoken"
symbolA = "HON"
symbolB = "JCI"
symbolC = "GOOGL"
symbolD = "ALRM"
symbolE = "REZI"
symbolF = "VVNT"

symbolAll = (symbolA,symbolB,symbolC,symbolD,symbolE,symbolF)

for symbol in symbolAll:

	urlProfile = "https://financialmodelingprep.com/api/v3/profile/" + symbol + "?apikey=" + api
	result3 = requests.get(urlProfile).json()

	for item3 in result3:
		beta = (item3['beta'])
		marketCap = (item3['mktCap'])

	urlBalanceSheet = "https://financialmodelingprep.com/api/v3/balance-sheet-statement/" + symbol + "?apikey=" + api
	result2 = requests.get(urlBalanceSheet).json()

	for item2 in result2:
		totalDebt = (item2['totalDebt'])
		longTermDebt = (item2['longTermDebt'])
		shortTermDebt = (item2['shortTermDebt'])


	url = "https://financialmodelingprep.com/api/v3/income-statement/" + symbol + "?apikey=" + api
	result = requests.get(url).json()

	for item in result:
		time = (item['date'])
		revenue = (item['revenue'])
		interestExpense = (item['interestExpense'])
		incomeTaxExpense = (item['incomeTaxExpense'])
		incomeBeforeTax = (item['incomeBeforeTax'])
		ebitda = (item['ebitda'])
		ebit = (item['incomeBeforeTax'])
		eps = (item['eps'])

		element_info = {
			'Symbol': symbol,
			'Date':time,
			'Revenue': revenue,
			'beta': beta,
			'Market Cap': marketCap,
			'Total Debt': totalDebt,
			'LT Debt': longTermDebt,
			'ST Debt': shortTermDebt,
			'Interest Expense': interestExpense,
			'Income Tax Expense': incomeTaxExpense,
			'Income Before Tax': incomeBeforeTax,
			'EBITDA': ebitda,
			'EBIT': ebit,
			'Earning per Share': eps
		}
	
		ccaSearch.append(element_info)

df = pd.DataFrame(ccaSearch)
print(df)
df.to_csv(yourfilename,encoding = 'utf_8_sig')

symbol = "CHPT"

url = "https://financialmodelingprep.com/api/v3/income-statement/" + symbol + "?apikey=" + api
result = requests.get(url).json()

for item in result:
	time = (item['date'])
	revenue = (item['revenue'])
	ebitda = (item['ebitda'])
	ebit = (item['incomeBeforeTax'])
	eps = (item['eps'])

	element_info = {
		'Symbol': symbol,
		'Date':time,
		'Revenue': revenue,
		'EBITDA': ebitda,
		'EBIT': ebit,
		'Earning per Share': eps
	}

	ccaSearch.append(element_info)

df = pd.DataFrame(ccaSearch)
print(df)

for symbol in symbolAll:

	url2 = "https://financialmodelingprep.com/api/v3/enterprise-values/" + symbol + "?apikey=" + api
	result2 = requests.get(url2).json()
# print(result)

	for item2 in result2:
		time2 = (item2['date'])
		ev = (item2['enterpriseValue'])
		marketCap = (item2['marketCapitalization'])
		stockPrice = (item2['stockPrice'])

		element_info2 = {
			'Symbol': symbol,
			'Date':time2,
			'Enterprise Value': ev,
			'Market Cap': marketCap,
			'Price': stockPrice
		}
	
		ccaSearch2.append(element_info2)

df2 = pd.DataFrame(ccaSearch2)
print(df2)

value_list = sh.values_update(uploadtogooglecell, params={'valueInputOption': 'USER_ENTERED'},body=dict(values=df.T.reset_index().T.values.tolist()))
value_list2 = sh.values_update(uploadtogooglecell, params={'valueInputOption': 'USER_ENTERED'},body=dict(values=df2.T.reset_index().T.values.tolist()))
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 1.7 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 2.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-e2d33e202214> in <module>
#      14
#      15 scope = ['https://www.googleapis.com/auth/spreadsheets','https://www.googleapis.com/auth/drive.file','https://www.googleapis.com/auth/drive']
# ---> 16 creds = ServiceAccountCredentials.from_json_keyfile_name('yourGooglesheetJSONpath',scope)
#      17 client = gspread.authorize(creds)
#      18 sh = client.open('yourgooglesheetfile')
#
# ...
